# %%
#First tradingEnv class
#todo add transaction cost
# add MACD indicator
# add RSI indicator
# add SMA indicator
# add EMA indicator
# meerdere crypto's toevoegen ( momenteel alleen BTC)
import numpy as np
import pandas as pd
class TradingEnv():
    def __init__(self, initial_investment=20000, Terminal_state= 2000):
        #investment
        self.initial_investment = initial_investment #initial investment 
        self.Terminal_state = Terminal_state  #terminal state, when the agent reach this state or below, the episode is over
        self.current_investment = initial_investment #current investment in a certain state
        self.non_invested = initial_investment #non invested money in a certain state
        self.invested = 0
        self.worth_history = [] #worth history in a certain episode
        # self.invested = [{'amount': 0, 'price_investment': 0, 'timestamp' : UNIX timestamp of investment}] #invested money 
        self.invested_amount = 0
        
        #rewards
        self.current_reward = 0 #current reward in a certain state
        self.total_reward = 0   #total reward in a certain episode
        self.reward_history = [] #reward history in a certain episode
        self.iterations = 0

        #states
        self.current_price = [0,0,0,0] #current price in a certain state [open,high,low,close]
        self.prev_price = np.zeros(20) #previous 20 prices to keep in memory to the state values
        self.done = False #if the episode is over
        self.current_unix_time = 0 #current unix time in a certain state
        self.macd = 0 #macd indicator
        
        
        #actions
        self.action = 0 #chosen action in a certain state
        self.action_history = [] #action history in a certain episode
        self.action_space = np.array([0,1,2]) #action space, 0 = hold, 1 = buy, 2 = sell first in the array 

        #Current state
        # self.current_state = self.get_current_state() #current state
        self.csv_to_dataframe() #convert csv's to one dataframe
        self.csv_index = 0 #index of the csv dataframe


    def get_current_state(self):
        #return current state price, and invested/non invested values as state
        return [self.current_price[0],self.current_price[1],self.current_price[2],self.current_price[3], self.invested, self.non_invested, self.invested_amount, self.current_unix_time, self.macd,self.sma10,self.sma20]
    # def calculate_macd(self):
    #     #calculate macd indicator
    #     print("macd")
    #     # print(self.df.iloc[self.csv_index - 12 : self.csv_index, 3])
    #     # print(self.df.iloc[self.csv_index - 12 : self.csv_index, 3].ewm(span=12, adjust=False).mean())
    #     macd = self.df.iloc[self.csv_index - 500 : self.csv_index, 3].ewm(span=500, adjust=False).mean()
    #     macd = macd.tolist()
    #     print('res',macd)
    #     # print('res',type(macd.tolist()))
    #     print("average macd", sum(macd) / len(macd))

        return macd
    def reset(self, demo=False):
        #reset the environment
        self.worth_history = []
        self.current_investment = self.initial_investment
        self.current_reward = 0
        self.total_reward = 0
        self.reward_history = []
        self.current_price = [0,0,0,0] #current price in a certain state [open,high,low,close]
        self.invested_amount = 0
        self.non_invested = self.initial_investment #non invested money in a certain state
        self.invested = 0
        self.worth_history = [] #worth history in a certain episode

        self.prev_price = np.zeros(20)
        self.action = 0
        self.action_history = []
        self.done = False
        self.current_unix_time = 0 #current unix time in a certain state
        self.csv_index = 0 #index of the csv dataframe


        #begin somewhere random in csv data 
        
        if demo == False:
            #last 6months as test set
            self.csv_index = np.random.randint(0, (len(self.df)/2) + 20000)
        else:
            self.csv_index = len(self.df) - 262975
        #get row csv_index from self.df
        self.current_price = self.df.iloc[self.csv_index, 3:7].values
        self.current_unix_time = self.df.iloc[self.csv_index, 0]
        
        self.macd =  self.df.iloc[self.csv_index, 10]
        self.sma20 =  self.df.iloc[self.csv_index, 9]
        self.sma10 =  self.df.iloc[self.csv_index, 11]






        return self.get_current_state(), self.done

    def step(self, action, interval = 1):
        self.iterations += 1
        self.action = action
        self.action_history.append(self.action)
        
        #calculate current reward
        self.current_reward = self.get_reward()
        self.done = self.is_done()
        #if the episode is over, give a big negative reward
        if self.done == True:
            self.current.reward - 1000000

        self.total_reward += self.current_reward
        self.reward_history.append(self.current_reward)

        #get next line of data in csv
        if self.csv_index < len(self.df) - 1:
            self.csv_index += interval
            self.current_price = self.df.iloc[self.csv_index, 3:7].values
            self.current_unix_time = self.df.iloc[self.csv_index, 0]
            self.macd =  self.df.iloc[self.csv_index, 10]
            self.sma20 =  self.df.iloc[self.csv_index, 9]
            self.sma10 =  self.df.iloc[self.csv_index, 11]

        else:
            self.done = True
        return self.get_current_state(), self.current_reward, self.done
        
    def get_reward(self):
        #reward function
        if self.action == 0:
            #hold do nothing
            reward = 0
        elif self.action == 1:
            #buy = invest 1/10 of non_invested money
            to_invest = self.non_invested / 10
            self.non_invested -= to_invest
            amount = to_invest / self.current_price[0]
            self.invested += to_invest
            self.invested_amount += amount
            reward = 0
        elif self.action == 2:
            #sell first bought in array of invested
            if self.invested > 0:
                amount = self.invested_amount
                price_investment = self.invested
                self.non_invested += amount * self.current_price[0]
                self.invested_amount = 0
                self.invested = 0

                reward = (amount * self.current_price[0]) - price_investment
            else:
                #hold, do nothing, nothing to sell
                reward = 0
        
        self.worth_history.append(self.calc_current_worth())
        return reward * ((self.calc_current_worth()/self.initial_investment)**2)



    def is_done(self):
        #terminal state
        if self.calc_current_worth() <= self.Terminal_state:
            return True
        else:
            return False

    def calc_current_worth(self):
        #calculate current worth
        return self.invested_amount * self.current_price[0] + self.non_invested

        
    def csv_to_dataframe(self):
        #convert csv's to one dataframe
        df2017 = pd.read_csv('./data/BTC-2017min.csv')
        df2018 = pd.read_csv('./data/BTC-2018min.csv')
        df2019 = pd.read_csv('./data/BTC-2019min.csv')
        df2020 = pd.read_csv('./data/BTC-2020min.csv')
        df2021 = pd.read_csv('./data/BTC-2021min.csv')

        #concat all dataframes
        df = pd.concat([df2017, df2018, df2019, df2020, df2021], ignore_index=True)
        #add new column named macd, that is the mean of the last 12 open values
        df['sma20000'] = df['open'].rolling(window=20000).mean()
        self.df = df
        df['macd20000'] = df['open'].rolling(window=20000).mean()**2
        self.df = df
        df['sma10000'] = df['open'].rolling(window=20000).mean()
        self.df = df
        #len = 2675301

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from keras.utils.generic_utils import get_custom_objects
import tensorflow as tf

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np

import gym, os
from gym import wrappers

from tensorflow.python.framework.ops import disable_eager_execution

disable_eager_execution()

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

tf.get_logger().setLevel('ERROR')
tf.config.experimental_run_functions_eagerly(False)
import pandas as pd
import numpy as np

import keras
import matplotlib.pyplot as plt
import seaborn as sns
from keras.utils.generic_utils import get_custom_objects

import keras
class Agent(object):
    def __init__(self, alpha, beta, gamma=0.99, n_actions=3,
                 layer1_size=1024, layer2_size=512, input_dims=11):
        self.gamma = gamma
        self.alpha = alpha
        self.beta = beta
        self.input_dims = input_dims
        self.fc1_dims = layer1_size
        self.fc2_dims = layer2_size
        self.n_actions = n_actions
        # hier nieuw netwerk maken of oude inladen
        # self.actor, self.critic, self.policy = self.build_actor_critic_network()
        self.critic = keras.models.load_model('worthreward/critic')
        self.policy = keras.models.load_model('worthreward/policy')
        self.actor = load_model('worthreward/actor')
        
        self.action_space = [i for i in range(n_actions)]
    # def custom_loss(self,y_true, y_pred):
    #     out = K.clip(y_pred, 1e-8, 1-1e-8)
    #     log_lik = y_true*K.log(out)
    #     delta = Input(shape=[1])
    #     return K.sum(-log_lik* Input(shape=[1]))

    def build_actor_critic_network(self):
        NN_input = Input(shape=(self.input_dims,))
        delta = Input(shape=[1])
        dense1 = Dense(self.fc1_dims, activation='relu')(NN_input)
        dense2 = Dense(self.fc2_dims, activation='relu')(dense1)
        probs = Dense(self.n_actions, activation='softmax')(dense2)
        values = Dense(1, activation='linear')(dense2)

        

        actor = Model(inputs=[NN_input, delta], outputs=[probs])

        actor.compile(optimizer=Adam(lr=self.alpha), loss='categorical_crossentropy')

        critic = Model(inputs=[NN_input], outputs=[values])

        critic.compile(optimizer=Adam(lr=self.beta), loss='mean_squared_error')

        policy = Model(inputs=[NN_input], outputs=[probs])

        return actor, critic, policy

    def choose_action(self, observation):
        try:    
            state = observation[np.newaxis, :]
            probabilities = self.policy.predict(state)[0]
            action = np.random.choice(self.action_space, p=probabilities)
            return action

        except Exception as ex:
            print("ex: ", ex)
            print(probabilities)
            return 0


    def learn(self, state, action, reward, state_, done):
        state = state[np.newaxis,:]
        state_ = state_[np.newaxis,:]
        critic_value_ = self.critic.predict(state_)
        critic_value = self.critic.predict(state)

        target = reward + self.gamma*critic_value_*(1-int(done))
        delta =  target - critic_value

        actions = np.zeros([1, self.n_actions])
        actions[np.arange(1), action] = 1

        self.actor.fit([state, delta], actions, verbose=0)

        self.critic.fit(state, target, verbose=0) 
        
        
        
        
def train():
    agent = Agent(alpha=0.01, beta=0.05)

    env = TradingEnv()
    score_history = []
    
    steps = []
    
    num_episodes = 10
    fullcounter = 0
    maxIterations = 50000
    allEpisodesWorth = []
    allEpisodesPrice = []
    AllEpisodesSold = []
    AllEpisodesBought = []


    for i in range(num_episodes):
        agent.policy.save('worthreward/policy')
        agent.critic.save('worthreward/critic')
        agent.actor.save('worthreward/actor')
        worth_history = []
        price_history = []
        bought = []
        sold = []
        done = False
        score = 0
        observation, done = env.reset()
        observation = np.asarray(observation)
        counter = 0
        lastBuy = -9000
        lastSold = -9999
        startprice = observation[0]
        while not done:
            counter += 1
            fullcounter += 1
            # env.render()
            action = agent.choose_action(observation)
            if counter - lastBuy > 10000:
                action = 1
            
            if action == 1:
                if counter - lastBuy > 250 and counter - lastSold > 100:

                    action = 1
                    lastBuy = counter
                else:
                    action = 0
            elif action == 2:
                if counter - lastBuy > 200 and counter - lastSold > 100 and env.invested>10:
                    action = 2
                    lastSold = counter
                else:
                    action = 0
            if counter > maxIterations:
                action = 2
                lastSold = counter
                sold.append(counter-1)
            if env.invested > 15000 and action == 1: 
                action = 0
            # pick a number between 0 and 1
            # if the number is less than epsilon, pick a random action
            # if the number is greater than epsilon, pick the action with the highest q value
            if np.random.random() < .001:
                action = 2
            steps.append(action)
            if action == 1:
                bought.append(counter-1)
            elif action == 2:
                sold.append(counter-1)


            observation_, reward, done = env.step(action, interval=5)
            if action == 1:
                print("invested", env.invested,"action: ", action ," Episode: ", i, "Step: ", counter, "current_worth: ", env.calc_current_worth())
                
            if action == 2:
                print("reward", reward,"action: ", action ," Episode: ", i, "Step: ", counter, "current_worth: ", env.calc_current_worth())
                # pass
                
            observation_ = np.asarray(observation_)
            agent.learn(observation, action, reward, observation_, done)
            observation = observation_
            score += reward
            worth_history.append(env.calc_current_worth())
            price_history.append(env.current_price)
            if counter > maxIterations:
                done = True
        endprice = observation[0]
        allEpisodesWorth.append(worth_history)
        allEpisodesPrice.append(price_history)
        AllEpisodesSold.append(sold)
        AllEpisodesBought.append(bought)

        score_history.append(score)
        avg_score = np.mean(score_history[-100:])
        print('episode: ', i,'worth: %.2f' % env.calc_current_worth(),
              'avg score %.2f' % avg_score)
        print("1buy&sell: startworth:", 20000, "endworth:", (20000/startprice)*endprice)

    # save model progress
    agent.policy.save('worthreward/policy')
    agent.critic.save('worthreward/critic')
    agent.actor.save('worthreward/actor')
    #make axes for 4 plots under eachother
    # print("allEpisodesWorth", len(allEpisodesWorth[0]))
    # print("allEpisodesPrice", len(allEpisodesPrice[0]))
    # print("AllEpisodesSold", len(AllEpisodesSold[0]))
    # print("AllEpisodesBought", len(AllEpisodesBought[0]))
    # print("startprice", startprice)
    # print("endprice", endprice)

    fig, axs = plt.subplots(len(allEpisodesWorth)+1, 1, figsize=(35, 50))
    #plot the price on first axis
    plot = sns.countplot(steps, ax=axs[0])
    plot.bar_label(plot.containers[0])
    #set plotje on first axis
    # sns.lineplot(price_history,ax=axs[3], color="red", label="price")
    # sns.lineplot(worth_history,ax=axs[3], color="blue", label="investment_worth")


    # axs[1].plot(price_history)


    # axs[1].plot(price_history, color="red", label="price")
    # axs[1].plot(worth_history, color="blue", label="investment_worth")
    # #print shapes of bought and sold worth_history and price_history
    # if len(bought) > 0:
    #     axs[1].plot(bought, [worth_history[i] for i in bought], 'o', color='green')
    #     axs[1].plot(bought, [price_history[i] for i in bought], 'o', color='green', label="bought")
    # if len(sold) > 0:
    #     axs[1].plot(sold, [worth_history[i] for i in sold], 'o', color='pink')
    #     axs[1].plot(sold, [price_history[i] for i in sold], 'o', color='pink', label="sold")

    # axs[1].legend()
    # axs[1].set_title("Price and worth over time")
    # axs[1].set_xlabel("Time")
    # axs[1].set_ylabel("Price/Worth")
    #foreach episode plot the worth and price in one plot 
    for i in range(len(allEpisodesWorth)):
        axs[i+1].plot(allEpisodesWorth[i], color="blue", label="investment_worth")
        axs[i+1].plot(allEpisodesPrice[i], color="red", label="price")
        #print shapes of bought and sold worth_history and price_history
        try:
            if len(AllEpisodesBought[i]) > 0:
                axs[i+1].plot(AllEpisodesBought[i], [allEpisodesWorth[i][j] for j in AllEpisodesBought[i]], 'o', color='green')
                axs[i+1].plot(AllEpisodesBought[i], [allEpisodesPrice[i][j] for j in AllEpisodesBought[i]], 'o', color='green', label="bought")
            else:
                print("no bought")
            if len(AllEpisodesSold[i]) > 0:
                axs[i+1].plot(AllEpisodesSold[i], [allEpisodesWorth[i][j] for j in AllEpisodesSold[i]], 'o', color='purple')
                axs[i+1].plot(AllEpisodesSold[i], [allEpisodesPrice[i][j] for j in AllEpisodesSold[i]], 'o', color='purple', label="sold")
            else:
                print("no sold")
        except Exception as ex:
            print("error")
            print(ex)
            print(AllEpisodesBought[i])
            print(AllEpisodesSold[i])
            print(len(allEpisodesWorth[i]))
            print(len(allEpisodesPrice[i]))
            print(allEpisodesWorth[i])
            print(allEpisodesPrice[i])
            print("end error")
            break

        axs[i+1].legend()
        axs[i+1].set_title(f"ep: {i} Price and worth over time")
        axs[i+1].set_xlabel("Time 1interval = 5min")
        axs[i+1].set_ylabel("Price/Worth USD")

       

    fig.show()


        

train()
# Out:
# c:\Users\cedri\anaconda3\envs\ResearchProj\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# reward 0.0 action:  2  Episode:  0 Step:  32 current_worth:  20000.0
# invested 2000.0 action:  1  Episode:  0 Step:  1001 current_worth:  20006.38183403521
# reward -229.3648157317385 action:  2  Episode:  0 Step:  1703 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  2956 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  3995 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  5472 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  6096 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  6410 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  7187 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  7655 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  8448 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  9067 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  9158 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  9593 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  10080 current_worth:  19765.152217872845
# reward 0.0 action:  2  Episode:  0 Step:  10472 current_worth:  19765.152217872845
# invested 1976.5152217872844 action:  1  Episode:  0 Step:  11002 current_worth:  19765.328234941535
# reward -107.50078071732769 action:  2  Episode:  0 Step:  12239 current_worth:  19653.831200651603
# reward 0.0 action:  2  Episode:  0 Step:  12513 current_worth:  19653.831200651603
# reward 0.0 action:  2  Episode:  0 Step:  12742 current_worth:  19653.831200651603
# reward 0.0 action:  2  Episode:  0 Step:  14242 current_worth:  19653.831200651603
# reward 0.0 action:  2  Episode:  0 Step:  15850 current_worth:  19653.831200651603
# reward 0.0 action:  2  Episode:  0 Step:  19114 current_worth:  19653.831200651603
# invested 1965.3831200651603 action:  1  Episode:  0 Step:  21003 current_worth:  19654.329484492493
# reward -12.306501053778838 action:  2  Episode:  0 Step:  21386 current_worth:  19641.070801421913
# reward 0.0 action:  2  Episode:  0 Step:  22315 current_worth:  19641.070801421913
# reward 0.0 action:  2  Episode:  0 Step:  26522 current_worth:  19641.070801421913
# reward 0.0 action:  2  Episode:  0 Step:  29321 current_worth:  19641.070801421913
# reward 0.0 action:  2  Episode:  0 Step:  29414 current_worth:  19641.070801421913
# reward 0.0 action:  2  Episode:  0 Step:  30895 current_worth:  19641.070801421913
# invested 1964.1070801421913 action:  1  Episode:  0 Step:  31004 current_worth:  19637.617980099985
# reward 366.09451096054573 action:  2  Episode:  0 Step:  32859 current_worth:  20006.912384898038
# reward 0.0 action:  2  Episode:  0 Step:  33056 current_worth:  20006.912384898038
# reward 0.0 action:  2  Episode:  0 Step:  33129 current_worth:  20006.912384898038
current_worth:  19932.48149938087
# reward 0.0 action:  2  Episode:  3 Step:  26709 current_worth:  19932.48149938087
# reward 0.0 action:  2  Episode:  3 Step:  29136 current_worth:  19932.48149938087
# reward 0.0 action:  2  Episode:  3 Step:  29582 current_worth:  19932.48149938087
# reward 0.0 action:  2  Episode:  3 Step:  30374 current_worth:  19932.48149938087
# reward 0.0 action:  2  Episode:  3 Step:  30497 current_worth:  19932.48149938087
# invested 1993.248149938087 action:  1  Episode:  3 Step:  31004 current_worth:  19934.512983685894
# reward -46.74599494232285 action:  2  Episode:  3 Step:  31293 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  31704 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  33508 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  33903 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  36224 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  36748 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  36991 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  37252 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  37878 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  38081 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  38185 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  38542 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  39550 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  39950 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  40250 current_worth:  19885.194176597546
# reward 0.0 action:  2  Episode:  3 Step:  40548 current_worth:  19885.194176597546
# invested 1988.5194176597547 action:  1  Episode:  3 Step:  41005 current_worth:  19884.381794705914
# reward -126.94833901072495 action:  2  Episode:  3 Step:  41454 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  42016 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  42072 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  42589 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  43905 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  45155 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  46523 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  48182 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  49733 current_worth:  19755.078539355523
# reward 0.0 action:  2  Episode:  3 Step:  50001 current_worth:  19755.078539355523
# episode:  3 worth: 19755.08 avg score -213.32
# 1buy&sell: startworth: 20000 endworth: 39681.71970511975
# reward 0.0 action:  2  Episode:  4 Step:  535 current_worth:  20000.0
# invested 2000.0 action:  1  Episode:  4 Step:  1001 current_worth:  20001.53420212672
# reward -16.039237889575848 action:  2  Episode:  4 Step:  1234 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  2318 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  3481 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  3799 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  4248 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  6068 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  6183 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  6411 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  8957 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  9337 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  9626 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  10181 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  10809 current_worth:  19983.934963937434
# reward 0.0 action:  2  Episode:  4 Step:  10976 current_worth:  19983.934963937434
# invested 1998.3934963937434 action:  1  Episode:  4 Step:  11002 current_worth:  19979.9680298049
# reward 77.43240720096858 action:  2  Episode:  4 Step:  14637 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  17222 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  18551 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  19278 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  19421 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  19657 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  20790 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  20884 current_worth:  20060.89796852008
# reward 0.0 action:  2  Episode:  4 Step:  20983 current_worth:  20060.89796852008
# invested 2006.089796852008 action:  1  Episode:  4 Step:  21003 current_worth:  20061.199124796854
# reward 130.37513688753114 action:  2  Episode:  4 Step:  21803 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  22377 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  23545 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  23804 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  23852 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  24814 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  25209 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  25251 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  27082 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  28661 current_worth:  20188.845467526164
# reward 0.0 action:  2  Episode:  4 Step:  30088 current_worth:  20188.845467526164
# invested 2018.8845467526164 action:  1  Episode:  4 Step:  31004 current_worth:  20187.814474322546
# reward -3.893659665147523 action:  2  Episode:  4 Step:  33218 current_worth:  20185.022861955826
# reward 0.0 action:  2  Episode:  4 Step:  34580 current_worth:  20185.022861955826
# reward 0.0 action:  2  Episode:  4 Step:  35653 current_worth:  20185.022861955826
# reward 0.0 action:  2  Episode:  4 Step:  36014 current_worth:  20185.022861955826
# reward 0.0 action:  2  Episode:  4 Step:  38071 current_worth:  20185.022861955826
# reward 0.0 action:  2  Episode:  4 Step:  38402 current_worth:  20185.022861955826
# reward 0.0 action:  2  Episode:  4 Step:  39297 current_worth:  20185.022861955826
# invested 2018.5022861955827 action:  1  Episode:  4 Step:  41005 current_worth:  20187.113864672498
# reward 14.581024634898705 action:  2  Episode:  4 Step:  42785 current_worth:  20199.31754866936
# reward 0.0 action:  2  Episode:  4 Step:
current_worth:  20026.07646973507
# reward 0.0 action:  2  Episode:  7 Step:  20332 current_worth:  20026.07646973507
# reward 0.0 action:  2  Episode:  7 Step:  20749 current_worth:  20026.07646973507
# invested 2002.6076469735071 action:  1  Episode:  7 Step:  21003 current_worth:  20026.40732431782
# reward 377.0576996618116 action:  2  Episode:  7 Step:  22335 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  22582 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  26317 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  26946 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  27877 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  29023 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  29186 current_worth:  20388.887712775162
# reward 0.0 action:  2  Episode:  7 Step:  29956 current_worth:  20388.887712775162
# invested 2038.8887712775163 action:  1  Episode:  7 Step:  31004 current_worth:  20387.501889049217
# reward 216.2928073992918 action:  2  Episode:  7 Step:  32221 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  33520 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  34568 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  34618 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  34854 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  35943 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  36182 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  38273 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  38281 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  38477 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  38845 current_worth:  20592.904939399894
# reward 0.0 action:  2  Episode:  7 Step:  40938 current_worth:  20592.904939399894
# invested 2059.2904939399896 action:  1  Episode:  7 Step:  41005 current_worth:  20594.806509700913
# reward -0.2335334762535498 action:  2  Episode:  7 Step:  41138 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  41595 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  41838 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  42691 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  44452 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  44561 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  45313 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  45314 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  45492 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  46633 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  46834 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  49286 current_worth:  20592.684655276436
# reward 0.0 action:  2  Episode:  7 Step:  50001 current_worth:  20592.684655276436
# episode:  7 worth: 20592.68 avg score 84.94
# 1buy&sell: startworth: 20000 endworth: 35002.033177764424
# reward 0.0 action:  2  Episode:  8 Step:  289 current_worth:  20000.0
# invested 2000.0 action:  1  Episode:  8 Step:  1001 current_worth:  20000.0
# reward 19.507763410644912 action:  2  Episode:  8 Step:  2102 current_worth:  20019.469837502107
# reward 0.0 action:  2  Episode:  8 Step:  3877 current_worth:  20019.469837502107
# reward 0.0 action:  2  Episode:  8 Step:  4366 current_worth:  20019.469837502107
# reward 0.0 action:  2  Episode:  8 Step:  5439 current_worth:  20019.469837502107
# reward 0.0 action:  2  Episode:  8 Step:  8702 current_worth:  20019.469837502107
# invested 2001.9469837502106 action:  1  Episode:  8 Step:  11002 current_worth:  20017.541876771626
# reward -4.486032947869528 action:  2  Episode:  8 Step:  13727 current_worth:  20014.990521798638
# reward 0.0 action:  2  Episode:  8 Step:  14410 current_worth:  20014.990521798638
# reward 0.0 action:  2  Episode:  8 Step:  15205 current_worth:  20014.990521798638
# reward 0.0 action:  2  Episode:  8 Step:  18018 current_worth:  20014.990521798638
# reward 0.0 action:  2  Episode:  8 Step:  18351 current_worth:  20014.990521798638
# reward 0.0 action:  2  Episode:  8 Step:  19829 current_worth:  20014.990521798638
# invested 2001.4990521798638 action:  1  Episode:  8 Step:  21003 current_worth:  20015.748366998552
# reward 0.391747788633252 action:  2  Episode:  8 Step:  21042 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  21345 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  22922 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  23648 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  25813 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  27310 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  28881 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  29749 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  30532 current_worth:  20015.381667708272
# reward 0.0 action:  2  Episode:  8 Step:  30999 current_worth:  20015.381667708272
# invested 2001.5381667708273 action:  1  Episode:  8 Step:  31004 current_worth:  20014.471153661583
# reward 49.225225191551246 action:  2  Episode:  8 Step:  31205 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  32378 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  32658 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  33910 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  36861 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  37262 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  37829 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  39455 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  40638 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  40964 current_worth:  20064.29193391882
# reward 0.0 action:  2  Episode:  8 Step:  40971 current_worth:  20064.29193391882
# invested 2006.4291933918819 action:  1  Episode:  8 Step:  41005 current_worth:  20064.687290074093
# reward 19.90436438561865 action:  2  Episode:  8 Step:  41750 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  41810 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  42117 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  42310 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  42342 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  43985 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  44033 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  46305 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  46924 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  48489 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  48611 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  49588 current_worth:  20084.03008997098
# reward 0.0 action:  2  Episode:  8 Step:  50001 current_worth:  20084.03008997098
# episode:  8 worth: 20084.03 avg score 84.89
# 1buy&sell: startworth: 20000 endworth: 26958.342464315512
# invested 2000.0 action:  1  Episode:  9 Step:  1001 current_worth:  19999.46903055988
# reward 94.40512440915481 action:  2  Episode:  9 Step:  3217 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  3373 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  4897 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  6646 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  8156 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  8828 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  10166 current_worth:  20093.528324305775
# reward 0.0 action:  2  Episode:  9 Step:  10623 current_worth:  20093.528324305775
# invested 2009.3528324305776 action:  1  Episode:  9 Step:  11002 current_worth:  20091.894293531514
# reward 6.025048892189476 action:  2  Episode:  9 Step:  11203 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  11962 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  12198 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  13467 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  13917 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  14285 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  14396 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  15121 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  17810 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  18915 current_worth:  20099.493872021027
# reward 0.0 action:  2  Episode:  9 Step:  20812 current_worth:  20099.493872021027
# invested 2009.9493872021026 action:  1  Episode:  9 Step:  21003 current_worth:  20101.30961624516
# reward -0.2188904028721647 action:  2  Episode:  9 Step:  21020 current_worth:  20099.277138625574
# reward 0.0 action:  2  Episode:  9 Step:  23430 current_worth:  20099.277138625574
# reward 0.0 action:  2  Episode:  9 Step:  23749 current_worth:  20099.277138625574
# reward 0.0 action:  2  Episode:  9 Step:  24361 current_worth:  20099.277138625574
# reward 0.0 action:  2  Episode:  9 Step:  27584 current_worth:  20099.277138625574
# reward 0.0 action:  2  Episode:  9 Step:  30177 current_worth:  20099.277138625574
# invested 2009.9277138625573 action:  1  Episode:  9 Step:  31004 current_worth:  20089.932454797352
# reward -202.53781361663917 action:  2  Episode:  9 Step:  31205 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  32022 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  32307 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  32612 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  32876 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  33283 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  33322 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  35132 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  37423 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  38197 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  39256 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  39315 current_worth:  19894.587321002644
# reward 0.0 action:  2  Episode:  9 Step:  40859 current_worth:  19894.587321002644
# invested 1989.4587321002643 action:  1  Episode:  9 Step:  41005 current_worth:  19895.06171919527
# reward 200.68432198472027 action:  2  Episode:  9 Step:  41206 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  42623 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  42782 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  43518 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  43783 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  44994 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  45516 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  45913 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  49606 current_worth:  20093.410100365843
# reward 0.0 action:  2  Episode:  9 Step:  50001 current_worth:  20093.410100365843
# episode:  9 worth: 20093.41 avg score 86.24
# 1buy&sell: startworth: 20000 endworth: 49300.02112859452
# c:\Users\cedri\anaconda3\envs\ResearchProj\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\cedri\AppData\Local\Temp\ipykernel_30324\1722587742.py:283: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # DEMO

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from keras.utils.generic_utils import get_custom_objects
import tensorflow as tf

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np

import gym, os
from gym import wrappers

from tensorflow.python.framework.ops import disable_eager_execution

disable_eager_execution()

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

tf.get_logger().setLevel('ERROR')
tf.config.experimental_run_functions_eagerly(False)
import pandas as pd
import numpy as np

import keras
import matplotlib.pyplot as plt
import seaborn as sns
from keras.utils.generic_utils import get_custom_objects

import keras
class Agent(object):
    def __init__(self, alpha, beta, gamma=0.99, n_actions=3,
                 layer1_size=1024, layer2_size=512, input_dims=11):
        self.gamma = gamma
        self.alpha = alpha
        self.beta = beta
        self.input_dims = input_dims
        self.fc1_dims = layer1_size
        self.fc2_dims = layer2_size
        self.n_actions = n_actions
        # hier nieuw netwerk maken of oude inladen
        # self.actor, self.critic, self.policy = self.build_actor_critic_network()
        self.critic = keras.models.load_model('worthreward/critic')
        self.policy = keras.models.load_model('worthreward/policy')
        self.actor = load_model('worthreward/actor')
        
        self.action_space = [i for i in range(n_actions)]
    # def custom_loss(self,y_true, y_pred):
    #     out = K.clip(y_pred, 1e-8, 1-1e-8)
    #     log_lik = y_true*K.log(out)
    #     delta = Input(shape=[1])
    #     return K.sum(-log_lik* Input(shape=[1]))

    def build_actor_critic_network(self):
        NN_input = Input(shape=(self.input_dims,))
        delta = Input(shape=[1])
        dense1 = Dense(self.fc1_dims, activation='relu')(NN_input)
        dense2 = Dense(self.fc2_dims, activation='relu')(dense1)
        probs = Dense(self.n_actions, activation='softmax')(dense2)
        values = Dense(1, activation='linear')(dense2)

        

        actor = Model(inputs=[NN_input, delta], outputs=[probs])

        actor.compile(optimizer=Adam(lr=self.alpha), loss='categorical_crossentropy')

        critic = Model(inputs=[NN_input], outputs=[values])

        critic.compile(optimizer=Adam(lr=self.beta), loss='mean_squared_error')

        policy = Model(inputs=[NN_input], outputs=[probs])

        return actor, critic, policy

    def choose_action(self, observation):
        try:    
            state = observation[np.newaxis, :]
            probabilities = self.policy.predict(state)[0]
            action = np.random.choice(self.action_space, p=probabilities)
            return action

        except Exception as ex:
            print("ex: ", ex)
            print(probabilities)
            return 0


    def learn(self, state, action, reward, state_, done):
        state = state[np.newaxis,:]
        state_ = state_[np.newaxis,:]
        critic_value_ = self.critic.predict(state_)
        critic_value = self.critic.predict(state)

        target = reward + self.gamma*critic_value_*(1-int(done))
        delta =  target - critic_value

        actions = np.zeros([1, self.n_actions])
        actions[np.arange(1), action] = 1

        self.actor.fit([state, delta], actions, verbose=0)

        self.critic.fit(state, target, verbose=0) 
        
        
        
        
def train():
    agent = Agent(alpha=0.01, beta=0.05)

    env = TradingEnv()
    score_history = []
    
    steps = []
    
    num_episodes = 1
    fullcounter = 0
    maxIterations = (262975 / 5) - 100

    allEpisodesWorth = []
    allEpisodesPrice = []
    AllEpisodesSold = []
    AllEpisodesBought = []


    for i in range(num_episodes):
        # agent.policy.save('worthreward/policy')
        # agent.critic.save('worthreward/critic')
        # agent.actor.save('worthreward/actor')
        worth_history = []
        price_history = []
        bought = []
        sold = []
        done = False
        score = 0
        observation, done = env.reset(demo=True)
        observation = np.asarray(observation)
        counter = 0
        lastBuy = -9000
        lastSold = -9999
        startprice = observation[0]
        while not done:
            counter += 1
            fullcounter += 1
            # env.render()
            action = agent.choose_action(observation)
            if counter - lastBuy > 10000:
                action = 1
            
            if action == 1:
                if counter - lastBuy > 250 and counter - lastSold > 100:

                    action = 1
                    lastBuy = counter
                else:
                    action = 0
            elif action == 2:
                if counter - lastBuy > 200 and counter - lastSold > 100 and env.invested>10:
                    action = 2
                    lastSold = counter
                else:
                    action = 0
            if counter > maxIterations:
                action = 2
                lastSold = counter
                sold.append(counter-1)
            if env.invested > 15000 and action == 1: 
                action = 0
            # pick a number between 0 and 1
            # if the number is less than epsilon, pick a random action
            # if the number is greater than epsilon, pick the action with the highest q value
            if np.random.random() < .001:
                action = 2
            steps.append(action)
            if action == 1:
                bought.append(counter-1)
            elif action == 2:
                sold.append(counter-1)


            observation_, reward, done = env.step(action, interval=5)
            # if action == 1:
            #     print("invested", env.invested,"action: ", action ," Episode: ", i, "Step: ", counter, "current_worth: ", env.calc_current_worth())
                
            # if action == 2:
            #     print("reward", reward,"action: ", action ," Episode: ", i, "Step: ", counter, "current_worth: ", env.calc_current_worth())
            #     # pass
                
            observation_ = np.asarray(observation_)
            agent.learn(observation, action, reward, observation_, done)
            observation = observation_
            score += reward
            worth_history.append(env.calc_current_worth())
            price_history.append(env.current_price)
            if counter > maxIterations:
                done = True
        endprice = observation[0]
        allEpisodesWorth.append(worth_history)
        allEpisodesPrice.append(price_history)
        AllEpisodesSold.append(sold)
        AllEpisodesBought.append(bought)

        score_history.append(score)
        avg_score = np.mean(score_history[-100:])
        print('episode: ', i,'worth: %.2f' % env.calc_current_worth(),
              'avg score %.2f' % avg_score)
        print("1buy&sell: startworth:", 20000, "endworth:", (20000/startprice)*endprice)

    # save model progress
    # agent.policy.save('worthreward/policy')
    # agent.critic.save('worthreward/critic')
    # agent.actor.save('worthreward/actor')
    #make axes for 4 plots under eachother
    # print("allEpisodesWorth", len(allEpisodesWorth[0]))
    # print("allEpisodesPrice", len(allEpisodesPrice[0]))
    # print("AllEpisodesSold", len(AllEpisodesSold[0]))
    # print("AllEpisodesBought", len(AllEpisodesBought[0]))
    # print("startprice", startprice)
    # print("endprice", endprice)

    fig, axs = plt.subplots(len(allEpisodesWorth)+1, 1, figsize=(35, 50))
    #plot the price on first axis
    plot = sns.countplot(steps, ax=axs[0])
    plot.bar_label(plot.containers[0])
    #set plotje on first axis
    # sns.lineplot(price_history,ax=axs[3], color="red", label="price")
    # sns.lineplot(worth_history,ax=axs[3], color="blue", label="investment_worth")


    # axs[1].plot(price_history)


    # axs[1].plot(price_history, color="red", label="price")
    # axs[1].plot(worth_history, color="blue", label="investment_worth")
    # #print shapes of bought and sold worth_history and price_history
    # if len(bought) > 0:
    #     axs[1].plot(bought, [worth_history[i] for i in bought], 'o', color='green')
    #     axs[1].plot(bought, [price_history[i] for i in bought], 'o', color='green', label="bought")
    # if len(sold) > 0:
    #     axs[1].plot(sold, [worth_history[i] for i in sold], 'o', color='pink')
    #     axs[1].plot(sold, [price_history[i] for i in sold], 'o', color='pink', label="sold")

    # axs[1].legend()
    # axs[1].set_title("Price and worth over time")
    # axs[1].set_xlabel("Time")
    # axs[1].set_ylabel("Price/Worth")
    #foreach episode plot the worth and price in one plot 
    for i in range(len(allEpisodesWorth)):
        axs[i+1].plot(allEpisodesWorth[i], color="blue", label="investment_worth")
        axs[i+1].plot(allEpisodesPrice[i], color="red", label="price")
        #print shapes of bought and sold worth_history and price_history
        try:
            if len(AllEpisodesBought[i]) > 0:
                axs[i+1].plot(AllEpisodesBought[i], [allEpisodesWorth[i][j] for j in AllEpisodesBought[i]], 'o', color='green')
                axs[i+1].plot(AllEpisodesBought[i], [allEpisodesPrice[i][j] for j in AllEpisodesBought[i]], 'o', color='green', label="bought")
            else:
                print("no bought")
            if len(AllEpisodesSold[i]) > 0:
                axs[i+1].plot(AllEpisodesSold[i], [allEpisodesWorth[i][j] for j in AllEpisodesSold[i]], 'o', color='purple')
                axs[i+1].plot(AllEpisodesSold[i], [allEpisodesPrice[i][j] for j in AllEpisodesSold[i]], 'o', color='purple', label="sold")
            else:
                print("no sold")
        except Exception as ex:
            print("error")
            print(ex)
            print(AllEpisodesBought[i])
            print(AllEpisodesSold[i])
            print(len(allEpisodesWorth[i]))
            print(len(allEpisodesPrice[i]))
            print(allEpisodesWorth[i])
            print(allEpisodesPrice[i])
            print("end error")
            break

        axs[i+1].legend()
        axs[i+1].set_title(f"ep: {i} Price and worth over time")
        axs[i+1].set_xlabel("Time 1interval = 5min")
        axs[i+1].set_ylabel("Price/Worth USD")

       

    fig.show()


        

train()
# Out:
# c:\Users\cedri\anaconda3\envs\ResearchProj\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# episode:  0 worth: 19285.98 avg score -682.25
# 1buy&sell: startworth: 20000 endworth: 17363.2096289106
# c:\Users\cedri\anaconda3\envs\ResearchProj\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\cedri\AppData\Local\Temp\ipykernel_30324\2926306438.py:284: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
